# %% [markdown]
# # Species Segmentation with Cluster Analysis

# %% [markdown]
# The Iris flower dataset is one of the most popular ones for machine learning. You can read a lot about it online and have probably already heard of it: https://en.wikipedia.org/wiki/Iris_flower_data_set
#
# We didn't want to use it in the lectures, but believe that it would be very interesting for you to try it out (and maybe read about it on your own).
#
# There are 4 features: sepal length, sepal width, petal length, and petal width.
#
# Start by creating 2 clusters. Then standardize the data and try again. Does it make a difference?
#
# Use the Elbow rule to determine how many clusters are there.

# %% [markdown]
# ## Import the relevant libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
from sklearn.cluster import KMeans
seaborn.set()

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load data from the csv file: <i> 'iris_dataset.csv'</i>.

# %%
df=pd.read_csv('datasets/iris_dataset.csv')

# %%
df.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 26            5.0          3.4           1.6          0.4
# 114           5.8          2.8           5.1          2.4
# 41            4.5          2.3           1.3          0.3
# 51            6.4          3.2           4.5          1.5
# 99            5.7          2.8           4.1          1.3

# %% [markdown]
# ## Plot the data

# %% [markdown]
# For this exercise, try to cluster the iris flowers by the shape of their sepal.
#
# <i> Use the 'sepal_length' and 'sepal_width' variables.</i>

# %%
x=df.iloc[:,0:2]
x.sample(5)
# Out:
#     sepal_length  sepal_width
# 92           5.8          2.6
# 71           6.1          2.8
# 30           4.8          3.1
# 99           5.7          2.8
# 4            5.0          3.6

# %% [markdown]
# # Clustering (unscaled data)

# %% [markdown]
# Separate the original data into 2 clusters.

# %%
km=KMeans(2)
km.fit(x)
# Out:
# c:\Users\Ghost\anaconda3\envs\class\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=2)

# %%
df_clust=x.copy()
df_clust['pred']=km.predict(x)
df_clust.sample(5)
# Out:
#      sepal_length  sepal_width  pred
# 133           6.3          2.8     0
# 46            5.1          3.8     1
# 66            5.6          3.0     1
# 20            5.4          3.4     1
# 64            5.6          2.9     1

# %%
plt.scatter(df_clust['sepal_length'],df_clust['sepal_width'],c=df_clust['pred'],cmap='rainbow')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.show()

# %% [markdown]
# # Standardize the variables

# %% [markdown]
# Import and use the <i> method </i> function from sklearn to standardize the data.

# %%
from sklearn import preprocessing
x_scaled=preprocessing.scale(x)

# %% [markdown]
# # Clustering (scaled data)

# %%
km_new=KMeans(2)
km_new.fit(x_scaled)
# Out:
# c:\Users\Ghost\anaconda3\envs\class\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=2)

# %%
df_clust=x.copy()
df_clust['pred']=km_new.predict(x_scaled)
df_clust.sample(5)
# Out:
#      sepal_length  sepal_width  pred
# 47            4.6          3.2     1
# 59            5.2          2.7     0
# 138           6.0          3.0     0
# 69            5.6          2.5     0
# 133           6.3          2.8     0

# %%
plt.scatter(df_clust['sepal_length'],df_clust['sepal_width'],c=df_clust['pred'],cmap='rainbow')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.show()

# %% [markdown]
# ## Take Advantage of the Elbow Method

# %% [markdown]
# ### WCSS

# %%
wcss=[]
for i in range(1,10):
    km=KMeans(i)
    km.fit(x_scaled)
    wcss.append(km.inertia_)
wcss
# Out:
# c:\Users\Ghost\anaconda3\envs\class\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\Ghost\anaconda3\envs\class\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\Ghost\anaconda3\envs\class\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %% [markdown]
# ### The Elbow Method

# %%
plt.plot(range(1,10),wcss)
plt.ylabel('WCSS')
plt.xlabel('Clusters')
plt.show()

# %% [markdown]
# How many clusters are there?

# %% [markdown]
# ##### 2 3 and 5

# %%
cl=[2,3,5]
for i in cl:
    km=KMeans(i)
    km.fit(x_scaled)
    df_clust=x.copy()
    df_clust['pred']=km.predict(x_scaled)
    plt.scatter(df_clust['sepal_length'],df_clust['sepal_width'],c=df_clust['pred'],cmap='rainbow')
    plt.xlabel('Sepal Length')
    plt.ylabel('Sepal Width')
    plt.title(f'Clusters:{i}')
    plt.show()
# Out:
# c:\Users\Ghost\anaconda3\envs\class\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\Ghost\anaconda3\envs\class\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\Ghost\anaconda3\envs\class\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
